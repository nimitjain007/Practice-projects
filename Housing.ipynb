# %%
import pandas as pd
import numpy as np

# %%
path = ("C:/Users/Lenovo/Desktop/New folder/htest.csv") # File path htest file

# %%
df = pd.read_csv(path) # Now i am going to read my file

# %%
path = ("C:/Users/Lenovo/Desktop/New folder/htrain.csv")# File path htrain file

# %%
data = pd.read_csv(path) # Now i am going to read my file

# %%
hf = df.append(data)# no mearge the data file htest+htrain

# %%
hf # Merge file data have a 1460 rows × 81 columns
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0      337          20       RL         86.0    14157   Pave   NaN      IR1
# 1     1018         120       RL          NaN     5814   Pave   NaN      IR1
# 2      929          20       RL          NaN    11838   Pave   NaN      Reg
# 3     1148          70       RL         75.0    12000   Pave   NaN      Reg
# 4     1227          60       RL         86.0    14598   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1163   289          20       RL          NaN     9819   Pave   NaN      IR1
# 1164   554          20       RL         67.0     8777   Pave   NaN      Reg
# 1165   196         160       RL         24.0     2280   Pave   NaN      Reg
# 1166    31          70  C (all)         50.0     8500   Pave  Pave      Reg
# 1167   617          60       RL          NaN     7861   Pave   NaN      IR1
#
# ...

# %%
hf.columns # i am checking a columns names
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
hf.describe(include="all")# Now i am decribe my data file there is nan value
# Out:
#                  Id   MSSubClass MSZoning  LotFrontage        LotArea Street  \
# count   1460.000000  1460.000000     1460  1201.000000    1460.000000   1460
# unique          NaN          NaN        5          NaN            NaN      2
# top             NaN          NaN       RL          NaN            NaN   Pave
# freq            NaN          NaN     1151          NaN            NaN   1454
# mean     730.500000    56.897260      NaN    70.049958   10516.828082    NaN
# std      421.610009    42.300571      NaN    24.284752    9981.264932    NaN
# min        1.000000    20.000000      NaN    21.000000    1300.000000    NaN
# 25%      365.750000    20.000000      NaN    59.000000    7553.500000    NaN
# 50%      730.500000    50.000000      NaN    69.000000    9478.500000    NaN
# 75%     1095.250000    70.000000      NaN    80.000000   11601.500000    NaN
# max     1460.000000   190.000000      NaN   313.000000  215245.000000    NaN
#
# ...

# %%
hf.head() # i am a checking top 5 data
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL         86.0    14157   Pave   NaN      IR1
# 1  1018         120       RL          NaN     5814   Pave   NaN      IR1
# 2   929          20       RL          NaN    11838   Pave   NaN      Reg
# 3  1148          70       RL         75.0    12000   Pave   NaN      Reg
# 4  1227          60       RL         86.0    14598   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         HLS    AllPub  ...        0    NaN   NaN         NaN       0      7
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      8
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      6
# 3         Bnk    AllPub  ...        0    NaN   NaN         NaN       0      7
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      1
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
hf.tail() # top 5 lowest data
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1163  289          20       RL          NaN     9819   Pave   NaN      IR1
# 1164  554          20       RL         67.0     8777   Pave   NaN      Reg
# 1165  196         160       RL         24.0     2280   Pave   NaN      Reg
# 1166   31          70  C (all)         50.0     8500   Pave  Pave      Reg
# 1167  617          60       RL          NaN     7861   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1163         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1164         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1165         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1166         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
# 1167         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
hf.dropna(subset=["Alley"],axis=0,inplace =True)
print="hf" # i am droping a nan data and retriev a missing data

# %%
hf # my data file
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 15     391          50       RL         50.0     8405   Pave  Grvl      Reg
# 43    1455          20       FV         62.0     7500   Pave  Pave      Reg
# 47     265          30       RM         30.0     5232   Pave  Grvl      IR3
# 50    1378          50       RL         60.0    10998   Pave  Grvl      Reg
# 72    1415          50       RL         64.0    13053   Pave  Pave      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1125   483          70       RM         50.0     2500   Pave  Pave      Reg
# 1130   498          50       RL         60.0     9120   Pave  Pave      Reg
# 1146  1388          50       RM         60.0     8520   Pave  Grvl      Reg
# 1162  1381          30       RL         45.0     8212   Pave  Grvl      Reg
# 1166    31          70  C (all)         50.0     8500   Pave  Pave      Reg
#
# ...

# %%
hf.dropna(subset=["SalePrice"],axis=0,inplace= True)
hf # i am droping a nan data and retriev a missing data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 31     426          60       RM         60.0     3378   Pave  Grvl      Reg
# 42    1365         160       FV         30.0     3180   Pave  Pave      Reg
# 51    1329          50       RM         60.0    10440   Pave  Grvl      Reg
# 58     897          30       RM         50.0     8765   Pave  Grvl      Reg
# 90     842          70       RM         60.0    10440   Pave  Grvl      Reg
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1125   483          70       RM         50.0     2500   Pave  Pave      Reg
# 1130   498          50       RL         60.0     9120   Pave  Pave      Reg
# 1146  1388          50       RM         60.0     8520   Pave  Grvl      Reg
# 1162  1381          30       RL         45.0     8212   Pave  Grvl      Reg
# 1166    31          70  C (all)         50.0     8500   Pave  Pave      Reg
#
# ...

# %%
hf.dropna(subset=["Fence"],axis=0,inplace= True)
hf # i am droping a nan data and retriev a missing data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 51    1329          50       RM         60.0    10440   Pave  Grvl      Reg
# 123    308          50       RM          NaN     7920   Pave  Grvl      IR1
# 299    631          70       RM         50.0     9000   Pave  Grvl      Reg
# 359   1264          70       RL         60.0    13515   Pave  Pave      Reg
# 430    205          50       RM         50.0     3500   Pave  Grvl      Reg
# 477    741          70       RM         60.0     9600   Pave  Grvl      Reg
# 511     22          45       RM         57.0     7449   Pave  Grvl      Reg
# 623    837          30       RM         90.0     8100   Pave  Pave      Reg
# 667    654          50       RM         60.0    10320   Pave  Grvl      Reg
# 685    440          50       RL         67.0    12354   Pave  Grvl      Reg
# 763    459          70       RM          NaN     5100   Pave  Grvl      Reg
# ...

# %%
hf.dropna(subset=["MiscVal"],axis=0,inplace= True)
hf # i am droping a nan data and retriev a missing data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 51    1329          50       RM         60.0    10440   Pave  Grvl      Reg
# 123    308          50       RM          NaN     7920   Pave  Grvl      IR1
# 299    631          70       RM         50.0     9000   Pave  Grvl      Reg
# 359   1264          70       RL         60.0    13515   Pave  Pave      Reg
# 430    205          50       RM         50.0     3500   Pave  Grvl      Reg
# 477    741          70       RM         60.0     9600   Pave  Grvl      Reg
# 511     22          45       RM         57.0     7449   Pave  Grvl      Reg
# 623    837          30       RM         90.0     8100   Pave  Pave      Reg
# 667    654          50       RM         60.0    10320   Pave  Grvl      Reg
# 685    440          50       RL         67.0    12354   Pave  Grvl      Reg
# 763    459          70       RM          NaN     5100   Pave  Grvl      Reg
# ...

# %%
hf["SalePrice"].tail(5) #  top 5 lowest data Now my target variable is Sales price so i can pridict
# Out:
# 828     110000.0
# 1033    105000.0
# 1130    184000.0
# 1146    136000.0
# 1166     40000.0
# Name: SalePrice, dtype: float64

# %%
hf["SalePrice"].head(5) #top 5 high data Now my target variable is Sales price so i can pridict
# Out:
# 51     256000.0
# 123     89500.0
# 299    124000.0
# 359    180500.0
# 430    110000.0
# Name: SalePrice, dtype: float64

# %%
hf["SalePrice"] = hf["SalePrice"]/hf["SalePrice"].max()

# %%
hf
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 51    1329          50       RM         60.0    10440   Pave  Grvl      Reg
# 123    308          50       RM          NaN     7920   Pave  Grvl      IR1
# 299    631          70       RM         50.0     9000   Pave  Grvl      Reg
# 359   1264          70       RL         60.0    13515   Pave  Pave      Reg
# 430    205          50       RM         50.0     3500   Pave  Grvl      Reg
# 477    741          70       RM         60.0     9600   Pave  Grvl      Reg
# 511     22          45       RM         57.0     7449   Pave  Grvl      Reg
# 623    837          30       RM         90.0     8100   Pave  Pave      Reg
# 667    654          50       RM         60.0    10320   Pave  Grvl      Reg
# 685    440          50       RL         67.0    12354   Pave  Grvl      Reg
# 763    459          70       RM          NaN     5100   Pave  Grvl      Reg
# ...

# %%
hf["SalePrice"] = (hf["SalePrice"]-hf["SalePrice"].min()/hf["SalePrice"].max()-hf["SalePrice"].min())

# %%
hf
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 51    1329          50       RM         60.0    10440   Pave  Grvl      Reg
# 123    308          50       RM          NaN     7920   Pave  Grvl      IR1
# 299    631          70       RM         50.0     9000   Pave  Grvl      Reg
# 359   1264          70       RL         60.0    13515   Pave  Pave      Reg
# 430    205          50       RM         50.0     3500   Pave  Grvl      Reg
# 477    741          70       RM         60.0     9600   Pave  Grvl      Reg
# 511     22          45       RM         57.0     7449   Pave  Grvl      Reg
# 623    837          30       RM         90.0     8100   Pave  Pave      Reg
# 667    654          50       RM         60.0    10320   Pave  Grvl      Reg
# 685    440          50       RL         67.0    12354   Pave  Grvl      Reg
# 763    459          70       RM          NaN     5100   Pave  Grvl      Reg
# ...

# %%
hf["SalePrice"] = (hf["SalePrice"]-hf["SalePrice"].mean())/hf["SalePrice"].std()

# %%
hf
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 51    1329          50       RM         60.0    10440   Pave  Grvl      Reg
# 123    308          50       RM          NaN     7920   Pave  Grvl      IR1
# 299    631          70       RM         50.0     9000   Pave  Grvl      Reg
# 359   1264          70       RL         60.0    13515   Pave  Pave      Reg
# 430    205          50       RM         50.0     3500   Pave  Grvl      Reg
# 477    741          70       RM         60.0     9600   Pave  Grvl      Reg
# 511     22          45       RM         57.0     7449   Pave  Grvl      Reg
# 623    837          30       RM         90.0     8100   Pave  Pave      Reg
# 667    654          50       RM         60.0    10320   Pave  Grvl      Reg
# 685    440          50       RL         67.0    12354   Pave  Grvl      Reg
# 763    459          70       RM          NaN     5100   Pave  Grvl      Reg
# ...

# %%
hf.describe()
# Out:
#                 Id  MSSubClass  LotFrontage      LotArea  OverallQual  \
# count    16.000000    16.00000    14.000000     16.00000    16.000000
# mean    643.250000    54.68750    60.285714   9018.00000     5.625000
# std     484.198513    11.75709     9.832666   2452.26233     1.204159
# min      22.000000    30.00000    50.000000   3500.00000     3.000000
# 25%     282.250000    50.00000    57.750000   8055.00000     5.000000
# 50%     564.500000    50.00000    60.000000   9060.00000     6.000000
# 75%     943.750000    70.00000    60.000000  10417.50000     6.000000
# max    1405.000000    70.00000    90.000000  13515.00000     8.000000
#
#        OverallCond    YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  \
# count    16.000000    16.000000     16.000000        16.0   16.000000  ...
# mean      6.375000  1919.437500   1968.000000         0.0  102.500000  ...
# std       1.087811    15.697001     22.108822         0.0  167.928953  ...
# ...

# %%
from sklearn.preprocessing import LabelEncoder
#label encoder will convert all the object type into numbers
le=LabelEncoder()

# %%
hf['SalePrice']=le.fit_transform(hf['SalePrice'])
hf['SaleCondition']=le.fit_transform(hf['SaleCondition'])
hf['SaleType']=le.fit_transform(hf['SaleType'])
hf
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 51    1329          50       RM         60.0    10440   Pave  Grvl      Reg
# 123    308          50       RM          NaN     7920   Pave  Grvl      IR1
# 299    631          70       RM         50.0     9000   Pave  Grvl      Reg
# 359   1264          70       RL         60.0    13515   Pave  Pave      Reg
# 430    205          50       RM         50.0     3500   Pave  Grvl      Reg
# 477    741          70       RM         60.0     9600   Pave  Grvl      Reg
# 511     22          45       RM         57.0     7449   Pave  Grvl      Reg
# 623    837          30       RM         90.0     8100   Pave  Pave      Reg
# 667    654          50       RM         60.0    10320   Pave  Grvl      Reg
# 685    440          50       RL         67.0    12354   Pave  Grvl      Reg
# 763    459          70       RM          NaN     5100   Pave  Grvl      Reg
# ...

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
hf.hist(figsize=(20,20))
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.pairplot(hf)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
YrSold = list(map(str,range(2005,2011)))
hf['SalePrice'].plot(kind = 'bar')
hf['SaleType'].plot(kind ='bar')
plt.ylabel('no of sales type')
plt.xlabel('sale price')
plt.show()

# %%
hf.sort_values(['SalePrice'],ascending =False ,axis = 0,inplace = True)

# %%
hf
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 51    1329          50       RM         60.0    10440   Pave  Grvl      Reg
# 1130   498          50       RL         60.0     9120   Pave  Pave      Reg
# 359   1264          70       RL         60.0    13515   Pave  Pave      Reg
# 763    459          70       RM          NaN     5100   Pave  Grvl      Reg
# 623    837          30       RM         90.0     8100   Pave  Pave      Reg
# 511     22          45       RM         57.0     7449   Pave  Grvl      Reg
# 1146  1388          50       RM         60.0     8520   Pave  Grvl      Reg
# 667    654          50       RM         60.0    10320   Pave  Grvl      Reg
# 477    741          70       RM         60.0     9600   Pave  Grvl      Reg
# 299    631          70       RM         50.0     9000   Pave  Grvl      Reg
# 430    205          50       RM         50.0     3500   Pave  Grvl      Reg
# ...

# %%
YrSold = list(map(str,range(2005,2011)))
hf.sort_values(['SalePrice'],ascending =False ,axis = 0,inplace = True)
hf_top5 = hf.head()
