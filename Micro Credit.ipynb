# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = "C:/Users/Lenovo/Desktop/New folder/Data.csv"

# %%
df = pd.read_csv(path)

# %%
df.shape
# Out:
# (209593, 37)

# %%
df.describe()
# Out:
#           Unnamed: 0          label            aon   daily_decr30  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean   104797.000000       0.875177    8112.343445    5381.402289
# std     60504.431823       0.330519   75696.082531    9220.623400
# min         1.000000       0.000000     -48.000000     -93.012667
# 25%     52399.000000       1.000000     246.000000      42.440000
# 50%    104797.000000       1.000000     527.000000    1469.175667
# 75%    157195.000000       1.000000     982.000000    7244.000000
# max    209593.000000       1.000000  999860.755168  265926.000000
#
#         daily_decr90       rental30       rental90  last_rech_date_ma  \
# count  209593.000000  209593.000000  209593.000000      209593.000000
# mean     6082.515068    2692.581910    3483.406534        3755.847800
# std     10918.812767    4308.586781    5770.461279       53905.892230
# min       -93.012667  -23737.140000  -24720.580000         -29.000000
# ...

# %%
df.isnull()
# Out:
#         Unnamed: 0  label  msisdn    aon  daily_decr30  daily_decr90  \
# 0            False  False   False  False         False         False
# 1            False  False   False  False         False         False
# 2            False  False   False  False         False         False
# 3            False  False   False  False         False         False
# 4            False  False   False  False         False         False
# ...            ...    ...     ...    ...           ...           ...
# 209588       False  False   False  False         False         False
# 209589       False  False   False  False         False         False
# 209590       False  False   False  False         False         False
# 209591       False  False   False  False         False         False
# 209592       False  False   False  False         False         False
#
#         rental30  rental90  last_rech_date_ma  last_rech_date_da  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 37 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Unnamed: 0            209593 non-null  int64
#  1   label                 209593 non-null  int64
#  2   msisdn                209593 non-null  object
#  3   aon                   209593 non-null  float64
#  4   daily_decr30          209593 non-null  float64
#  5   daily_decr90          209593 non-null  float64
#  6   rental30              209593 non-null  float64
#  7   rental90              209593 non-null  float64
#  8   last_rech_date_ma     209593 non-null  float64
#  9   last_rech_date_da     209593 non-null  float64
#  10  last_rech_amt_ma      209593 non-null  int64
#  11  cnt_ma_rech30         209593 non-null  int64
#  12  fr_ma_rech30          209593 non-null  float64
#  13  sumamnt_ma_rech30     209593 non-null  float64
# ...

# %%
df.corr()
# Out:
#                       Unnamed: 0     label       aon  daily_decr30  \
# Unnamed: 0              1.000000  0.000403 -0.002048      0.002739
# label                   0.000403  1.000000 -0.003785      0.168298
# aon                    -0.002048 -0.003785  1.000000      0.001104
# daily_decr30            0.002739  0.168298  0.001104      1.000000
# daily_decr90            0.003077  0.166150  0.000374      0.977704
# rental30               -0.003906  0.058085 -0.000960      0.442066
# rental90               -0.003459  0.075521 -0.000790      0.458977
# last_rech_date_ma      -0.001853  0.003728  0.001692      0.000487
# last_rech_date_da      -0.001133  0.001711 -0.001693     -0.001636
# last_rech_amt_ma       -0.001064  0.131804  0.004256      0.275837
# cnt_ma_rech30           0.003320  0.237331 -0.003148      0.451385
# fr_ma_rech30            0.003181  0.001330 -0.001163     -0.000577
# sumamnt_ma_rech30       0.000123  0.202828  0.000707      0.636536
# ...

# %%
df.cov()
# Out:
#                         Unnamed: 0        label           aon  daily_decr30  \
# Unnamed: 0            3.660786e+09     8.062059 -9.381608e+06  1.528190e+06
# label                 8.062059e+00     0.109243 -9.469799e+01  5.129028e+02
# aon                  -9.381608e+06   -94.697991  5.729897e+09  7.708031e+05
# daily_decr30          1.528190e+06   512.902811  7.708031e+05  8.501990e+07
# daily_decr90          2.032456e+06   599.614153  3.091816e+05  9.843355e+07
# rental30             -1.018376e+06    82.716404 -3.131466e+05  1.756234e+07
# rental90             -1.207829e+06   144.036314 -3.450965e+05  2.442088e+07
# last_rech_date_ma    -6.043062e+06    66.425265  6.904121e+06  2.421359e+05
# last_rech_date_da    -3.657974e+06    30.185050 -6.840408e+06 -8.049119e+05
# last_rech_amt_ma     -1.526930e+05   103.279806  7.638476e+05  6.029833e+06
# cnt_ma_rech30         8.548832e+02     0.333858 -1.014180e+03  1.771404e+04
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  label       msisdn    aon  daily_decr30  daily_decr90  \
# 0           1      0  21408I70789  272.0   3055.050000   3065.150000
# 1           2      1  76462I70374  712.0  12122.000000  12124.750000
# 2           3      1  17943I70372  535.0   1398.000000   1398.000000
# 3           4      1  55773I70781  241.0     21.228000     21.228000
# 4           5      1  03813I82730  947.0    150.619333    150.619333
#
#    rental30  rental90  last_rech_date_ma  last_rech_date_da  ...  \
# 0    220.13    260.13                2.0                0.0  ...
# 1   3691.26   3691.26               20.0                0.0  ...
# 2    900.13    900.13                3.0                0.0  ...
# 3    159.42    159.42               41.0                0.0  ...
# 4   1098.90   1098.90                4.0                0.0  ...
#
#    maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 0              6.0                 0.0          2.0            12
# ...

# %%
df_no_missing = df.dropna()
df_no_missing
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0  21408I70789   272.0   3055.050000   3065.150000
# 1                2      1  76462I70374   712.0  12122.000000  12124.750000
# 2                3      1  17943I70372   535.0   1398.000000   1398.000000
# 3                4      1  55773I70781   241.0     21.228000     21.228000
# 4                5      1  03813I82730   947.0    150.619333    150.619333
# ...            ...    ...          ...     ...           ...           ...
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
# ...

# %%
df_cleaned = df.dropna(how='all')
df_cleaned
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0  21408I70789   272.0   3055.050000   3065.150000
# 1                2      1  76462I70374   712.0  12122.000000  12124.750000
# 2                3      1  17943I70372   535.0   1398.000000   1398.000000
# 3                4      1  55773I70781   241.0     21.228000     21.228000
# 4                5      1  03813I82730   947.0    150.619333    150.619333
# ...            ...    ...          ...     ...           ...           ...
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90',
#        'rental30', 'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %%
df.dropna(axis=1,how='all')
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0  21408I70789   272.0   3055.050000   3065.150000
# 1                2      1  76462I70374   712.0  12122.000000  12124.750000
# 2                3      1  17943I70372   535.0   1398.000000   1398.000000
# 3                4      1  55773I70781   241.0     21.228000     21.228000
# 4                5      1  03813I82730   947.0    150.619333    150.619333
# ...            ...    ...          ...     ...           ...           ...
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
# ...

# %%
df.fillna(0)
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0  21408I70789   272.0   3055.050000   3065.150000
# 1                2      1  76462I70374   712.0  12122.000000  12124.750000
# 2                3      1  17943I70372   535.0   1398.000000   1398.000000
# 3                4      1  55773I70781   241.0     21.228000     21.228000
# 4                5      1  03813I82730   947.0    150.619333    150.619333
# ...            ...    ...          ...     ...           ...           ...
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
# ...

# %%
df
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0  21408I70789   272.0   3055.050000   3065.150000
# 1                2      1  76462I70374   712.0  12122.000000  12124.750000
# 2                3      1  17943I70372   535.0   1398.000000   1398.000000
# 3                4      1  55773I70781   241.0     21.228000     21.228000
# 4                5      1  03813I82730   947.0    150.619333    150.619333
# ...            ...    ...          ...     ...           ...           ...
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
# ...

# %%
df['last_rech_date_da'].fillna(df['last_rech_date_da'].mean(), inplace=True)
df
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0  21408I70789   272.0   3055.050000   3065.150000
# 1                2      1  76462I70374   712.0  12122.000000  12124.750000
# 2                3      1  17943I70372   535.0   1398.000000   1398.000000
# 3                4      1  55773I70781   241.0     21.228000     21.228000
# 4                5      1  03813I82730   947.0    150.619333    150.619333
# ...            ...    ...          ...     ...           ...           ...
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0                int64
# label                     int64
# msisdn                   object
# aon                     float64
# daily_decr30            float64
# daily_decr90            float64
# rental30                float64
# rental90                float64
# last_rech_date_ma       float64
# last_rech_date_da       float64
# last_rech_amt_ma          int64
# cnt_ma_rech30             int64
# fr_ma_rech30            float64
# sumamnt_ma_rech30       float64
# medianamnt_ma_rech30    float64
# medianmarechprebal30    float64
# cnt_ma_rech90             int64
# fr_ma_rech90              int64
# sumamnt_ma_rech90         int64
# medianamnt_ma_rech90    float64
# medianmarechprebal90    float64
# cnt_da_rech30           float64
# fr_da_rech30            float64
# cnt_da_rech90             int64
# fr_da_rech90              int64
# cnt_loans30               int64
# amnt_loans30              int64
# maxamnt_loans30         float64
# medianamnt_loans30      float64
# ...

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 209588    False
# 209589    False
# 209590    False
# 209591    False
# 209592    False
# Length: 209593, dtype: bool

# %%
df = df.drop_duplicates()
df
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0  21408I70789   272.0   3055.050000   3065.150000
# 1                2      1  76462I70374   712.0  12122.000000  12124.750000
# 2                3      1  17943I70372   535.0   1398.000000   1398.000000
# 3                4      1  55773I70781   241.0     21.228000     21.228000
# 4                5      1  03813I82730   947.0    150.619333    150.619333
# ...            ...    ...          ...     ...           ...           ...
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
# ...

# %%
df
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0  21408I70789   272.0   3055.050000   3065.150000
# 1                2      1  76462I70374   712.0  12122.000000  12124.750000
# 2                3      1  17943I70372   535.0   1398.000000   1398.000000
# 3                4      1  55773I70781   241.0     21.228000     21.228000
# 4                5      1  03813I82730   947.0    150.619333    150.619333
# ...            ...    ...          ...     ...           ...           ...
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
# ...

# %%
df[['label','msisdn']]
# Out:
#         label       msisdn
# 0           0  21408I70789
# 1           1  76462I70374
# 2           1  17943I70372
# 3           1  55773I70781
# 4           1  03813I82730
# ...       ...          ...
# 209588      1  22758I85348
# 209589      1  95583I84455
# 209590      1  28556I85350
# 209591      1  59712I82733
# 209592      1  65061I85339
#
# [209593 rows x 2 columns]

# %%
#Now i am chechking null in data.
df.isnull().sum()
# I obeserve there is no null value in data.
# Out:
# Unnamed: 0              0
# label                   0
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# ...

# %%
df.msisdn.unique()
# Out:
# array(['21408I70789', '76462I70374', '17943I70372', ..., '22758I85348',
#        '59712I82733', '65061I85339'], dtype=object)

# %%
df.msisdn.value_counts()
# Out:
# 47819I90840    7
# 04581I85330    7
# 43430I70786    6
# 22038I88658    6
# 55809I89238    6
#               ..
# 28261I95204    1
# 51355I88688    1
# 89979I70375    1
# 75762I88649    1
# 31119I88659    1
# Name: msisdn, Length: 186243, dtype: int64

# %%
df[df.label==False]
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0                1      0  21408I70789   272.0   3055.050000   3065.150000
# 11              12      0  82417I90848    82.0     65.166667     65.166667
# 15              16      0  24075I89239  1037.0     12.000000     12.000000
# 16              17      0  82053I85350  1583.0   1000.000000   1000.000000
# 21              22      0  75522I70784   378.0    514.693333    515.200000
# ...            ...    ...          ...     ...           ...           ...
# 209547      209548      0  32172I88688   153.0   5670.733333   5672.200000
# 209549      209550      0  59552I90843   843.0    729.235000    758.470000
# 209554      209555      0  49076I89233   744.0   1454.491667   1461.750000
# 209571      209572      0  59768I84453   827.0   1867.668667   1881.180000
# 209584      209585      0  70387I89237   945.0      0.000000      0.000000
#
# ...

# %%
df[df.label==True]
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 1                2      1  76462I70374   712.0  12122.000000  12124.750000
# 2                3      1  17943I70372   535.0   1398.000000   1398.000000
# 3                4      1  55773I70781   241.0     21.228000     21.228000
# 4                5      1  03813I82730   947.0    150.619333    150.619333
# 5                6      1  35819I70783   568.0   2257.362667   2261.460000
# ...            ...    ...          ...     ...           ...           ...
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
# ...

# %%
df.groupby('msisdn').max()
# Out:
#              Unnamed: 0  label            aon  daily_decr30  daily_decr90  \
# msisdn
# 00004I82738      116848      1     171.000000      9.290000      9.290000
# 00005I96753       41260      1     207.000000     79.706000     79.706000
# 00010I89237       55790      1     352.000000  20941.368000  21070.120000
# 00011I90846      160530      1     798.000000  19280.000000  20599.900000
# 00012I70784      116051      1     128.000000  26379.000000  28595.720000
# ...                 ...    ...            ...           ...           ...
# 99995I88658       26482      1     984.000000   9273.950000   9315.540000
# 99997I88648      186750      1  517563.753063   5405.000000   6626.790000
# 99998I70781      187783      1     281.000000  23406.000000  25668.290000
# 99998I95202      129536      1     195.000000      7.916667      7.916667
# 99998I95206       59020      1     150.000000     43.288667     43.288667
#
# ...

# %%
a=df.groupby('label')['msisdn'].max()
print(a)
# Out:
# label
# 0    99994I85330
# 1    99998I95206
# Name: msisdn, dtype: object

# %%
df['label'].value_counts().plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.head(1)
# Out:
#    Unnamed: 0  label       msisdn    aon  daily_decr30  daily_decr90  \
# 0           1      0  21408I70789  272.0       3055.05       3065.15
#
#    rental30  rental90  last_rech_date_ma  last_rech_date_da  ...  \
# 0    220.13    260.13                2.0                0.0  ...
#
#    maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 0              6.0                 0.0          2.0            12
#
#    maxamnt_loans90  medianamnt_loans90  payback30  payback90  pcircle  \
# 0                6                 0.0       29.0       29.0      UPW
#
#         pdate
# 0  2016-07-20
#
# [1 rows x 37 columns]

# %%
df['payback30'].nunique()
#Average payback time in days over last 30 days
# Out:
# 1363

# %%
df['payback90'].nunique()
#Average payback time in days over last 90 days
# Out:
# 2381

# %%
#Now i am chechking averege main account balance over last 30 days
df['rental30'].nunique()
# Out:
# 132148

# %%
df['rental90'].nunique()
#Average main account balance over last 90 days
# Out:
# 141033

# %%
df['last_rech_date_ma'].nunique()
#Number of days till last recharge of main account
# Out:
# 1186

# %%
df['last_rech_date_da'].nunique()
#Number of days till last recharge of data account
# Out:
# 1174

# %%
df['maxamnt_loans30'].nunique()
#Maximum loan amount taken by user in last 30 says
# Out:
# 1050

# %%
df['medianamnt_loans30'].nunique()
#Meadian of amounts of taken by the user in last 30 days
# Out:
# 6

# %%
df['cnt_loans90'].nunique()
#Number of loans taken by user in last 90 days
# Out:
# 1110

# %%
df['fr_ma_rech90'].nunique()
#Frequency of main account recharged in last 90 days
# Out:
# 89

# %%
df['pcircle'].nunique()
# Out:
# 1

# %%
df.daily_decr30.unique().sum()
# Out:
# 923773965.8906665

# %%
df.payback90.unique().sum()
# Out:
# 58964.05358267889

# %%
df.rental30.unique().sum()
# Out:
# 499125727.28

# %%
df.last_rech_date_ma.unique().sum()
# Out:
# 785959564.9580457

# %%
df.last_rech_date_da.unique().sum()
# Out:
# 777863417.7540181

# %%
df.pdate.unique().sum()
# Out:
# '2016-07-202016-08-102016-08-192016-06-062016-06-222016-07-022016-07-052016-08-052016-06-152016-06-082016-06-122016-06-202016-06-292016-06-162016-08-032016-06-242016-07-042016-07-032016-07-012016-08-082016-06-262016-06-232016-07-062016-07-092016-06-102016-06-072016-06-272016-08-112016-06-302016-06-192016-07-262016-08-142016-06-142016-06-212016-06-252016-06-282016-06-112016-07-272016-07-232016-08-162016-08-152016-06-022016-06-052016-08-022016-07-282016-07-182016-08-182016-07-162016-07-292016-07-212016-06-032016-06-132016-08-012016-07-132016-07-102016-06-092016-07-152016-07-112016-08-092016-08-122016-07-222016-06-042016-07-242016-06-182016-08-132016-06-172016-08-072016-07-122016-08-062016-07-192016-08-212016-08-042016-07-252016-07-302016-08-172016-07-082016-07-142016-06-012016-07-072016-07-172016-07-312016-08-20'

# %%
df.pcircle.unique().sum()
# Out:
# 'UPW'

# %%
df.label.unique().sum() #Flag indicating whether the user paid back the credit amount within 5 days of issuing the loan{1:success, 0:failure}
# Out:
# 1

# %%
df.groupby('label').mean()
# Out:
#           Unnamed: 0          aon  daily_decr30  daily_decr90     rental30  \
# label
# 0      104732.412316  8870.998799   1272.376756   1278.817736  2029.914812
# 1      104806.211873  8004.139590   5967.455497   6767.646423  2787.095360
#
#           rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  \
# label
# 0      2329.486376        3223.694134        3470.381002       1237.045830
# 1      3647.985363        3831.746662        3746.692974       2182.462408
#
#        cnt_ma_rech30  ...  cnt_loans30  amnt_loans30  maxamnt_loans30  \
# label                 ...
# 0           1.303417  ...     1.431313      8.873634       271.873754
# 1           4.359530  ...     2.948340     19.246834       275.055959
#
#        medianamnt_loans30  cnt_loans90  amnt_loans90  maxamnt_loans90  \
# label
# 0                0.028285    15.703549      9.642382         6.234386
# 1                0.057700    18.922749     25.642590         6.769990
#
# ...

# %%
df.groupby('label').max()
# Out:
#        Unnamed: 0       msisdn            aon   daily_decr30  daily_decr90  \
# label
# 0          209585  99994I85330  995148.346759  103764.858667     103884.61
# 1          209593  99998I95206  999860.755168  265926.000000     320630.00
#
#         rental30   rental90  last_rech_date_ma  last_rech_date_da  \
# label
# 0       74214.44   91595.72      997676.760075      999171.809410
# 1      198926.11  200148.11      998650.377733      997920.294292
#
#        last_rech_amt_ma  ...  maxamnt_loans30  medianamnt_loans30  \
# label                    ...
# 0                 55000  ...     99571.106262                 1.0
# 1                 55000  ...     99864.560864                 3.0
#
#        cnt_loans90  amnt_loans90  maxamnt_loans90  medianamnt_loans90  \
# label
# 0      4894.101713           156               12                 1.0
# 1      4997.517944           438               12                 3.0
#
#        payback30  payback90  pcircle       pdate
# label
# ...

# %%
df.groupby('label').std()
# Out:
#          Unnamed: 0           aon  daily_decr30  daily_decr90     rental30  \
# label
# 0      60636.167540  79707.888724   3167.434293   3181.302208  3756.422682
# 1      60485.779499  75106.039025   9641.760633  11446.417423  4373.508766
#
#           rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  \
# label
# 0      4352.824562       49421.872120       51637.471409       2078.089580
# 1      5926.903342       54515.086753       53618.087208       2386.379103
#
#        cnt_ma_rech30  ...  cnt_loans30  amnt_loans30  maxamnt_loans30  \
# label                 ...
# 0           2.021023  ...     1.100109      7.213658      4258.032852
# 1           4.353103  ...     2.645055     18.007875      4243.451929
#
#        medianamnt_loans30  cnt_loans90  amnt_loans90  maxamnt_loans90  \
# label
# 0                0.152583   219.017386      8.976451         1.162510
# 1                0.225595   225.607456     27.516137         2.197498
#
# ...

# %%
df.groupby('label').var()
# Out:
#          Unnamed: 0           aon  daily_decr30  daily_decr90      rental30  \
# label
# 0      3.676745e+09  6.353348e+09  1.003264e+07  1.012068e+07  1.411071e+07
# 1      3.658530e+09  5.640917e+09  9.296355e+07  1.310205e+08  1.912758e+07
#
#            rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  \
# label
# 0      1.894708e+07       2.442521e+09       2.666428e+09      4.318456e+06
# 1      3.512818e+07       2.971895e+09       2.874899e+09      5.694805e+06
#
#        cnt_ma_rech30  ...  cnt_loans30  amnt_loans30  maxamnt_loans30  \
# label                 ...
# 0           4.084533  ...     1.210239     52.036858     1.813084e+07
# 1          18.949508  ...     6.996317    324.283569     1.800688e+07
#
#        medianamnt_loans30   cnt_loans90  amnt_loans90  maxamnt_loans90  \
# label
# 0                0.023282  47968.615464     80.576665         1.351429
# 1                0.050893  50898.724398    757.137787         4.828995
#
# ...

# %%
#0 Faliure
#1 Success

Success = df[df.label==1]
Faliure = df[df.label==0]
print(Success)
print(Faliure)
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 1                2      1  76462I70374   712.0  12122.000000  12124.750000
# 2                3      1  17943I70372   535.0   1398.000000   1398.000000
# 3                4      1  55773I70781   241.0     21.228000     21.228000
# 4                5      1  03813I82730   947.0    150.619333    150.619333
# 5                6      1  35819I70783   568.0   2257.362667   2261.460000
# ...            ...    ...          ...     ...           ...           ...
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
# ...

# %%
Success.shape
# Out:
# (183431, 37)

# %%
Faliure.shape
# Out:
# (26162, 37)

# %%
Success.payback30.describe()
# Out:
# count    183431.000000
# mean          3.559715
# std           8.633455
# min           0.000000
# 25%           0.000000
# 50%           1.500000
# 75%           4.000000
# max         171.500000
# Name: payback30, dtype: float64

# %%
df.groupby('payback30').mean()
# Out:
#                Unnamed: 0     label            aon  daily_decr30  \
# payback30
# 0.000000    104781.627568  0.789939    8201.024419   2754.285348
# 1.000000    104166.728390  0.991663    6786.956711   9899.146020
# 1.041667    154996.000000  1.000000     380.000000   2480.167000
# 1.055556     83910.000000  1.000000  728804.427083   1881.506000
# 1.066667    186148.000000  1.000000     264.000000  90339.000000
# ...                   ...       ...            ...           ...
# 169.000000  116574.000000  1.000000     944.000000   4838.000000
# 169.500000  162258.000000  1.000000     874.000000   5004.000000
# 170.000000   17999.000000  1.000000     339.000000   7050.000000
# 170.500000   46275.000000  1.000000    1293.000000   1750.000000
# 171.500000  149160.000000  1.000000     928.000000  12883.000000
#
#             daily_decr90      rental30      rental90  last_rech_date_ma  \
# payback30
# 0.000000     3110.766070   1960.652445   2500.089346        3818.950585
# ...

# %%
Success_sample=Success.sample(n=183431)
print(Success_sample)
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 88977        88978      1  36948I88689   362.0  11099.733333  11136.000000
# 152596      152597      1  80110I70371   475.0     24.649333     24.649333
# 176223      176224      1  61863I88648   915.0   2882.014000   2907.110000
# 161770      161771      1  58988I82736   163.0   1444.466667   1458.000000
# 160978      160979      1  72494I70375   453.0  14437.000000  19923.430000
# ...            ...    ...          ...     ...           ...           ...
# 166881      166882      1  64418I70783   354.0   2280.000000   2280.000000
# 176573      176574      1  07259I88812   502.0     53.529000     53.529000
# 61694        61695      1  06030I82732   486.0  13993.000000  15346.170000
# 62429        62430      1  25211I70372   500.0   3701.000000   3733.280000
# 38618        38619      1  31876I82730  1018.0  33744.000000  33774.500000
#
# ...

# %%
new_data=pd.concat([Success_sample,Faliure],axis=1) #added row wise bcz of axis =0,if axis=1:added column wise
new_data
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0              NaN    NaN          NaN     NaN           NaN           NaN
# 1              2.0    1.0  76462I70374   712.0  12122.000000  12124.750000
# 2              3.0    1.0  17943I70372   535.0   1398.000000   1398.000000
# 3              4.0    1.0  55773I70781   241.0     21.228000     21.228000
# 4              5.0    1.0  03813I82730   947.0    150.619333    150.619333
# ...            ...    ...          ...     ...           ...           ...
# 209588    209589.0    1.0  22758I85348   404.0    151.872333    151.872333
# 209589    209590.0    1.0  95583I84455  1075.0     36.936000     36.936000
# 209590    209591.0    1.0  28556I85350  1013.0  11843.111667  11904.350000
# 209591    209592.0    1.0  59712I82733  1732.0  12488.228333  12574.370000
# 209592    209593.0    1.0  65061I85339  1581.0   4489.362000   4534.820000
#
# ...

# %%
new_data.head(5)
# Out:
#    Unnamed: 0  label       msisdn    aon  daily_decr30  daily_decr90  \
# 0         NaN    NaN          NaN    NaN           NaN           NaN
# 1         2.0    1.0  76462I70374  712.0  12122.000000  12124.750000
# 2         3.0    1.0  17943I70372  535.0   1398.000000   1398.000000
# 3         4.0    1.0  55773I70781  241.0     21.228000     21.228000
# 4         5.0    1.0  03813I82730  947.0    150.619333    150.619333
#
#    rental30  rental90  last_rech_date_ma  last_rech_date_da  ...  \
# 0       NaN       NaN                NaN                NaN  ...
# 1   3691.26   3691.26               20.0                0.0  ...
# 2    900.13    900.13                3.0                0.0  ...
# 3    159.42    159.42               41.0                0.0  ...
# 4   1098.90   1098.90                4.0                0.0  ...
#
#    maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 0              6.0                 0.0          2.0          12.0
# ...

# %%
new_data.tail(5)
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 209588    209589.0    1.0  22758I85348   404.0    151.872333    151.872333
# 209589    209590.0    1.0  95583I84455  1075.0     36.936000     36.936000
# 209590    209591.0    1.0  28556I85350  1013.0  11843.111667  11904.350000
# 209591    209592.0    1.0  59712I82733  1732.0  12488.228333  12574.370000
# 209592    209593.0    1.0  65061I85339  1581.0   4489.362000   4534.820000
#
#         rental30  rental90  last_rech_date_ma  last_rech_date_da  ...  \
# 209588   1089.19   1089.19                1.0                0.0  ...
# 209589   1728.36   1728.36                4.0                0.0  ...
# 209590   5861.83   8893.20                3.0                0.0  ...
# 209591    411.83    984.58                2.0               38.0  ...
# 209592    483.92    631.20               13.0                0.0  ...
#
#         maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# ...

# %%
x=new_data.drop(columns='payback30',axis=1)
x
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 0              NaN    NaN          NaN     NaN           NaN           NaN
# 1              2.0    1.0  76462I70374   712.0  12122.000000  12124.750000
# 2              3.0    1.0  17943I70372   535.0   1398.000000   1398.000000
# 3              4.0    1.0  55773I70781   241.0     21.228000     21.228000
# 4              5.0    1.0  03813I82730   947.0    150.619333    150.619333
# ...            ...    ...          ...     ...           ...           ...
# 209588    209589.0    1.0  22758I85348   404.0    151.872333    151.872333
# 209589    209590.0    1.0  95583I84455  1075.0     36.936000     36.936000
# 209590    209591.0    1.0  28556I85350  1013.0  11843.111667  11904.350000
# 209591    209592.0    1.0  59712I82733  1732.0  12488.228333  12574.370000
# 209592    209593.0    1.0  65061I85339  1581.0   4489.362000   4534.820000
#
# ...

# %%
y=new_data['payback30']
y
# Out:
#         payback30  payback30
# 0             NaN       29.0
# 1        0.000000        NaN
# 2        0.000000        NaN
# 3        0.000000        NaN
# 4        2.333333        NaN
# ...           ...        ...
# 209588   1.000000        NaN
# 209589   1.000000        NaN
# 209590   4.000000        NaN
# 209591   0.000000        NaN
# 209592   0.000000        NaN
#
# [209593 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
# split the data into training data and testing data
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=22)

x.shape , x_train.shape , x_test.shape
# Out:
# ((209593, 72), (167674, 72), (41919, 72))
